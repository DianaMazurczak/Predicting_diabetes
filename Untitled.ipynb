# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo

cdc_diabetes_health_indicators = fetch_ucirepo(id=891)

# data (as pandas dataframes)
X = cdc_diabetes_health_indicators.data.features
y = cdc_diabetes_health_indicators.data.targets

# %%
# variable information
information = pd.DataFrame(cdc_diabetes_health_indicators.variables)
information[['name', 'type', 'description', 'missing_values']]
# Out:
# Index(['name', 'role', 'type', 'demographic', 'description', 'units',
#        'missing_values'],
#       dtype='object')
#                     name     type                                        description missing_values
# 0                     ID  Integer                                         Patient ID             no
# 1        Diabetes_binary   Binary        0 = no diabetes 1 = prediabetes or diabetes             no
# 2                 HighBP   Binary                         0 = no high BP 1 = high BP             no
# 3               HighChol   Binary       0 = no high cholesterol 1 = high cholesterol             no
# 4              CholCheck   Binary  0 = no cholesterol check in 5 years 1 = yes ch...             no
# 5                    BMI  Integer                                    Body Mass Index             no
# 6                 Smoker   Binary  Have you smoked at least 100 cigarettes in you...             no
# 7                 Stroke   Binary       (Ever told) you had a stroke. 0 = no 1 = yes             no
# 8   HeartDiseaseorAttack   Binary  coronary heart disease (CHD) or myocardial inf...             no
# 9           PhysActivity   Binary  physical activity in past 30 days - not includ...             no
# 10                Fruits   Binary  Consume Fruit 1 or more times per day 0 = no 1...             no
# 11               Veggies   Binary  Consume Vegetables 1 or more times per day 0 =...             no
# 12     HvyAlcoholConsump   Binary  Heavy drinkers (adult men having more than 14 ...             no
# 13         AnyHealthcare   Binary  Have any kind of health care coverage, includi...             no
# 14           NoDocbcCost   Binary  Was there a time in the past 12 months when yo...             no
# 15               GenHlth  Integer  Would you say that in general your health is: ...             no
# 16              MentHlth  Integer  Now thinking about your mental health, which i...             no
# 17              PhysHlth  Integer  Now thinking about your physical health, which...             no
# 18              DiffWalk   Binary  Do you have serious difficulty walking or clim...             no
# 19                   Sex   Binary                                0 = female 1 = male             no
# 20                   Age  Integer  13-level age category (_AGEG5YR see codebook) ...             no
# 21             Education  Integer  Education level (EDUCA see codebook) scale 1-6...             no
# 22                Income  Integer  Income scale (INCOME2 see codebook) scale 1-8 ...             no
